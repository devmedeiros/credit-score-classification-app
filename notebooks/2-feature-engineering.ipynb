# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.options.mode.chained_assignment = None

# %%
df = pd.read_csv('../data/interim/credit-score.csv', index_col='ID')
df.head()
# Out:
#        Customer_ID     Month   Age Occupation  Annual_Income  \
# ID
# 0x1602   CUS_0xd40   January  23.0  Scientist       19114.12
# 0x1603   CUS_0xd40  February  23.0  Scientist       19114.12
# 0x1604   CUS_0xd40     March  23.0  Scientist       19114.12
# 0x1605   CUS_0xd40     April  23.0  Scientist       19114.12
# 0x1606   CUS_0xd40       May  23.0  Scientist       19114.12
#
#         Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# ID
# 0x1602            1824.843333                  3              4.0
# 0x1603            1824.843333                  3              4.0
# 0x1604            1824.843333                  3              4.0
# 0x1605            1824.843333                  3              4.0
# 0x1606            1824.843333                  3              4.0
#
#         Interest_Rate  Num_of_Loan  \
# ID
# 0x1602            3.0          4.0
# 0x1603            3.0          4.0
# 0x1604            3.0          4.0
# 0x1605            3.0          4.0
# 0x1606            3.0          4.0
#
#                                              Type_of_Loan  \
# ID
# 0x1602  Auto Loan, Credit-Builder Loan, Personal Loan,...
# 0x1603  Auto Loan, Credit-Builder Loan, Personal Loan,...
# 0x1604  Auto Loan, Credit-Builder Loan, Personal Loan,...
# 0x1605  Auto Loan, Credit-Builder Loan, Personal Loan,...
# 0x1606  Auto Loan, Credit-Builder Loan, Personal Loan,...
#
#         Delay_from_due_date  Num_of_Delayed_Payment  Changed_Credit_Limit  \
# ID
# 0x1602                    3                     7.0                 11.27
# 0x1603                   -1                     6.0                 11.27
# 0x1604                    3                     7.0                 10.27
# 0x1605                    5                     4.0                  6.27
# 0x1606                    6                     6.0                 11.27
#
#         Num_Credit_Inquiries Credit_Mix  Outstanding_Debt  \
# ID
# 0x1602                   4.0       Good            809.98
# 0x1603                   4.0       Good            809.98
# 0x1604                   4.0       Good            809.98
# 0x1605                   4.0       Good            809.98
# 0x1606                   4.0       Good            809.98
#
#         Credit_Utilization_Ratio Payment_of_Min_Amount  Total_EMI_per_month  \
# ID
# 0x1602                 26.822620                    No            49.574949
# 0x1603                 31.944960                    No            49.574949
# 0x1604                 28.609352                    No            49.574949
# 0x1605                 31.377862                    No            49.574949
# 0x1606                 24.797347                    No            49.574949
#
#         Amount_invested_monthly  Monthly_Balance Credit_Score  \
# ID
# 0x1602                80.415295       312.494089         Good
# 0x1603               118.280222       284.629162         Good
# 0x1604                81.699521       331.209863         Good
# 0x1605               199.458074       223.451310         Good
# 0x1606                41.420153       341.489231         Good
#
#         Credit_History_Age_Formated
# ID
# 0x1602                        265.0
# 0x1603                        266.0
# 0x1604                        267.0
# 0x1605                        268.0
# 0x1606                        269.0

# %%
loan_types = []
for index in df.index:
    temp = df.Type_of_Loan[index].replace('and ', '').split(', ')
    for i in temp: #loan in temp array
        if i not in loan_types: #if loan is not in loan_types
            loan_types.append(i) #add it

# %%
for loan in loan_types:
    df[loan] = 0
    for index in df.index:
        temp = df.Type_of_Loan[index].replace('and ', '').split(', ')
        if loan in temp:
            df.loc[index, loan] = 1

# %%
df[loan_types].head()
# Out:
#         Auto Loan  Credit-Builder Loan  Personal Loan  Home Equity Loan  \
# ID
# 0x1602          1                    1              1                 1
# 0x1603          1                    1              1                 1
# 0x1604          1                    1              1                 1
# 0x1605          1                    1              1                 1
# 0x1606          1                    1              1                 1
#
#         Not Specified  Mortgage Loan  Student Loan  Debt Consolidation Loan  \
# ID
# 0x1602              0              0             0                        0
# 0x1603              0              0             0                        0
# 0x1604              0              0             0                        0
# 0x1605              0              0             0                        0
# 0x1606              0              0             0                        0
#
#         Payday Loan
# ID
# 0x1602            0
# 0x1603            0
# 0x1604            0
# 0x1605            0
# 0x1606            0

# %%
month = {
    'January': 1,
    'February': 2,
    'March': 3,
    'April': 4,
    'May': 5,
    'June': 6,
    'July': 7,
    'August': 8
}
df.Month.replace(month, inplace=True)
df.Month = df.Month.astype(int)

# %%
credit_mix = {
    'Standard': 0,
    'Good': 1,
    'Bad': -1
}
df.Credit_Mix.replace(credit_mix, inplace=True)
df.Credit_Mix = df.Credit_Mix.astype(int)

# %%
credit_score = {
    'Standard': 0,
    'Poor': -1,
    'Good': 1
}
df.Credit_Score.replace(credit_score, inplace=True)
df.Credit_Score = df.Credit_Score.astype(int)

# %%
df.tail()
# Out:
#         Customer_ID  Month   Age Occupation  Annual_Income  \
# ID
# 0x25fe9  CUS_0x942c      4  25.0   Mechanic       39628.99
# 0x25fea  CUS_0x942c      5  25.0   Mechanic       39628.99
# 0x25feb  CUS_0x942c      6  25.0   Mechanic       39628.99
# 0x25fec  CUS_0x942c      7  25.0   Mechanic       39628.99
# 0x25fed  CUS_0x942c      8  25.0   Mechanic       39628.99
#
#          Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# ID
# 0x25fe9            3359.415833                  4              6.0
# 0x25fea            3359.415833                  4              6.0
# 0x25feb            3359.415833                  4              6.0
# 0x25fec            3359.415833                  4              6.0
# 0x25fed            3359.415833                  4              6.0
#
#          Interest_Rate  Num_of_Loan                 Type_of_Loan  \
# ID
# 0x25fe9            7.0          2.0  Auto Loan, and Student Loan
# 0x25fea            7.0          2.0  Auto Loan, and Student Loan
# 0x25feb            7.0          2.0  Auto Loan, and Student Loan
# 0x25fec            7.0          2.0  Auto Loan, and Student Loan
# 0x25fed            7.0          2.0  Auto Loan, and Student Loan
#
#          Delay_from_due_date  Num_of_Delayed_Payment  Changed_Credit_Limit  \
# ID
# 0x25fe9                   23                     7.0                  11.5
# 0x25fea                   18                     7.0                  11.5
# 0x25feb                   27                     6.0                  11.5
# 0x25fec                   20                     6.4                  11.5
# 0x25fed                   18                     6.0                  11.5
#
#          Num_Credit_Inquiries  Credit_Mix  Outstanding_Debt  \
# ID
# 0x25fe9                   3.0           1            502.38
# 0x25fea                   3.0           1            502.38
# 0x25feb                   3.0           1            502.38
# 0x25fec                   3.0           1            502.38
# 0x25fed                   3.0           1            502.38
#
#          Credit_Utilization_Ratio Payment_of_Min_Amount  Total_EMI_per_month  \
# ID
# 0x25fe9                 34.663572                    No            35.104023
# 0x25fea                 40.565631                    No            35.104023
# 0x25feb                 41.255522                    No            35.104023
# 0x25fec                 33.638208                    No            35.104023
# 0x25fed                 34.192463                    No            35.104023
#
#          Amount_invested_monthly  Monthly_Balance  Credit_Score  \
# ID
# 0x25fe9                60.971333       479.866228            -1
# 0x25fea                54.185950       496.651610            -1
# 0x25feb                24.028477       516.809083            -1
# 0x25fec               251.672582       319.164979             0
# 0x25fed               167.163865       393.673696            -1
#
#          Credit_History_Age_Formated  Auto Loan  Credit-Builder Loan  \
# ID
# 0x25fe9                        378.0          1                    0
# 0x25fea                        379.0          1                    0
# 0x25feb                        380.0          1                    0
# 0x25fec                        381.0          1                    0
# 0x25fed                        382.0          1                    0
#
#          Personal Loan  Home Equity Loan  Not Specified  Mortgage Loan  \
# ID
# 0x25fe9              0                 0              0              0
# 0x25fea              0                 0              0              0
# 0x25feb              0                 0              0              0
# 0x25fec              0                 0              0              0
# 0x25fed              0                 0              0              0
#
#          Student Loan  Debt Consolidation Loan  Payday Loan
# ID
# 0x25fe9             1                        0            0
# 0x25fea             1                        0            0
# 0x25feb             1                        0            0
# 0x25fec             1                        0            0
# 0x25fed             1                        0            0

# %%
#df['Previous_Credit_Score']
df[df.Customer_ID == 'CUS_0x942c']
# Out:
#         Customer_ID  Month   Age Occupation  Annual_Income  \
# ID
# 0x25fe6  CUS_0x942c      1  24.0   Mechanic       39628.99
# 0x25fe7  CUS_0x942c      2  25.0   Mechanic       39628.99
# 0x25fe8  CUS_0x942c      3  25.0   Mechanic       39628.99
# 0x25fe9  CUS_0x942c      4  25.0   Mechanic       39628.99
# 0x25fea  CUS_0x942c      5  25.0   Mechanic       39628.99
# 0x25feb  CUS_0x942c      6  25.0   Mechanic       39628.99
# 0x25fec  CUS_0x942c      7  25.0   Mechanic       39628.99
# 0x25fed  CUS_0x942c      8  25.0   Mechanic       39628.99
#
#          Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# ID
# 0x25fe6            3359.415833                  4              6.0
# 0x25fe7            3359.415833                  4              6.0
# 0x25fe8            3359.415833                  4              6.0
# 0x25fe9            3359.415833                  4              6.0
# 0x25fea            3359.415833                  4              6.0
# 0x25feb            3359.415833                  4              6.0
# 0x25fec            3359.415833                  4              6.0
# 0x25fed            3359.415833                  4              6.0
#
#          Interest_Rate  Num_of_Loan                 Type_of_Loan  \
# ID
# 0x25fe6            7.0          2.0  Auto Loan, and Student Loan
# 0x25fe7            7.0          2.0  Auto Loan, and Student Loan
# 0x25fe8            7.0          2.0  Auto Loan, and Student Loan
# 0x25fe9            7.0          2.0  Auto Loan, and Student Loan
# 0x25fea            7.0          2.0  Auto Loan, and Student Loan
# 0x25feb            7.0          2.0  Auto Loan, and Student Loan
# 0x25fec            7.0          2.0  Auto Loan, and Student Loan
# 0x25fed            7.0          2.0  Auto Loan, and Student Loan
#
#          Delay_from_due_date  Num_of_Delayed_Payment  Changed_Credit_Limit  \
# ID
# 0x25fe6                   23                     6.4                   9.5
# 0x25fe7                   23                     6.4                  11.5
# 0x25fe8                   20                     6.0                   9.5
# 0x25fe9                   23                     7.0                  11.5
# 0x25fea                   18                     7.0                  11.5
# 0x25feb                   27                     6.0                  11.5
# 0x25fec                   20                     6.4                  11.5
# 0x25fed                   18                     6.0                  11.5
#
#          Num_Credit_Inquiries  Credit_Mix  Outstanding_Debt  \
# ID
# 0x25fe6                   3.0           1            502.38
# 0x25fe7                   3.0           1            502.38
# 0x25fe8                   3.0           1            502.38
# 0x25fe9                   3.0           1            502.38
# 0x25fea                   3.0           1            502.38
# 0x25feb                   3.0           1            502.38
# 0x25fec                   3.0           1            502.38
# 0x25fed                   3.0           1            502.38
#
#          Credit_Utilization_Ratio Payment_of_Min_Amount  Total_EMI_per_month  \
# ID
# 0x25fe6                 32.991333                    No            35.104023
# 0x25fe7                 29.135447                    No         58638.000000
# 0x25fe8                 39.323569                    No            35.104023
# 0x25fe9                 34.663572                    No            35.104023
# 0x25fea                 40.565631                    No            35.104023
# 0x25feb                 41.255522                    No            35.104023
# 0x25fec                 33.638208                    No            35.104023
# 0x25fed                 34.192463                    No            35.104023
#
#          Amount_invested_monthly  Monthly_Balance  Credit_Score  \
# ID
# 0x25fe6               401.196481       189.641080            -1
# 0x25fe7               180.733095       400.104466             0
# 0x25fe8               140.581403       410.256158            -1
# 0x25fe9                60.971333       479.866228            -1
# 0x25fea                54.185950       496.651610            -1
# 0x25feb                24.028477       516.809083            -1
# 0x25fec               251.672582       319.164979             0
# 0x25fed               167.163865       393.673696            -1
#
#          Credit_History_Age_Formated  Auto Loan  Credit-Builder Loan  \
# ID
# 0x25fe6                        375.0          1                    0
# 0x25fe7                        376.0          1                    0
# 0x25fe8                        377.0          1                    0
# 0x25fe9                        378.0          1                    0
# 0x25fea                        379.0          1                    0
# 0x25feb                        380.0          1                    0
# 0x25fec                        381.0          1                    0
# 0x25fed                        382.0          1                    0
#
#          Personal Loan  Home Equity Loan  Not Specified  Mortgage Loan  \
# ID
# 0x25fe6              0                 0              0              0
# 0x25fe7              0                 0              0              0
# 0x25fe8              0                 0              0              0
# 0x25fe9              0                 0              0              0
# 0x25fea              0                 0              0              0
# 0x25feb              0                 0              0              0
# 0x25fec              0                 0              0              0
# 0x25fed              0                 0              0              0
#
#          Student Loan  Debt Consolidation Loan  Payday Loan
# ID
# 0x25fe6             1                        0            0
# 0x25fe7             1                        0            0
# 0x25fe8             1                        0            0
# 0x25fe9             1                        0            0
# 0x25fea             1                        0            0
# 0x25feb             1                        0            0
# 0x25fec             1                        0            0
# 0x25fed             1                        0            0

# %%
len(df.Customer_ID.unique())
# Out:
# 12500
