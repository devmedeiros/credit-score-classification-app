# %% [markdown]
# # Machine Learning

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../data/processed/credit-score.csv', index_col=['ID', 'Customer_ID'])

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# I'll be dropping all the features that I won't be using.

# %%
df.drop(columns=['Occupation', 'Monthly_Inhand_Salary', 'Interest_Rate', 'Type_of_Loan', 'Delay_from_due_date',
                 'Changed_Credit_Limit', 'Num_Credit_Inquiries', 'Credit_Mix', 'Amount_invested_monthly',
                 'Monthly_Balance', 'Num_of_Loan', 'Outstanding_Debt', 'Not_Specified', 'Month'], inplace=True)
df.head()
# Out:
#                      Age  Annual_Income  Num_Bank_Accounts  Num_Credit_Card  \
# ID     Customer_ID
# 0x1602 CUS_0xd40    23.0       19114.12                3.0              4.0
# 0x1603 CUS_0xd40    23.0       19114.12                3.0              4.0
# 0x1604 CUS_0xd40    23.0       19114.12                3.0              4.0
# 0x1605 CUS_0xd40    23.0       19114.12                3.0              4.0
# 0x1606 CUS_0xd40    23.0       19114.12                3.0              4.0
#
#                     Num_of_Delayed_Payment  Credit_Utilization_Ratio  \
# ID     Customer_ID
# 0x1602 CUS_0xd40                       7.0                 26.822620
# 0x1603 CUS_0xd40                       6.0                 31.944960
# 0x1604 CUS_0xd40                       7.0                 28.609352
# 0x1605 CUS_0xd40                       4.0                 31.377862
# 0x1606 CUS_0xd40                       6.0                 24.797347
#
#                    Payment_of_Min_Amount  Total_EMI_per_month  Credit_Score  \
# ID     Customer_ID
# 0x1602 CUS_0xd40                      No            49.574949             1
# 0x1603 CUS_0xd40                      No            49.574949             1
# 0x1604 CUS_0xd40                      No            49.574949             1
# 0x1605 CUS_0xd40                      No            49.574949             1
# 0x1606 CUS_0xd40                      No            49.574949             1
#
#                     Credit_History_Age_Formated  Auto_Loan  \
# ID     Customer_ID
# 0x1602 CUS_0xd40                          265.0          1
# 0x1603 CUS_0xd40                          266.0          1
# 0x1604 CUS_0xd40                          267.0          1
# 0x1605 CUS_0xd40                          268.0          1
# 0x1606 CUS_0xd40                          269.0          1
#
#                     Credit-Builder_Loan  Personal_Loan  Home_Equity_Loan  \
# ID     Customer_ID
# 0x1602 CUS_0xd40                      1              1                 1
# 0x1603 CUS_0xd40                      1              1                 1
# 0x1604 CUS_0xd40                      1              1                 1
# 0x1605 CUS_0xd40                      1              1                 1
# 0x1606 CUS_0xd40                      1              1                 1
#
#                     Mortgage_Loan  Student_Loan  Debt_Consolidation_Loan  \
# ID     Customer_ID
# 0x1602 CUS_0xd40                0             0                        0
# 0x1603 CUS_0xd40                0             0                        0
# 0x1604 CUS_0xd40                0             0                        0
# 0x1605 CUS_0xd40                0             0                        0
# 0x1606 CUS_0xd40                0             0                        0
#
#                     Payday_Loan  Missed_Payment_Day
# ID     Customer_ID
# 0x1602 CUS_0xd40              0                   1
# 0x1603 CUS_0xd40              0                   0
# 0x1604 CUS_0xd40              0                   1
# 0x1605 CUS_0xd40              0                   1
# 0x1606 CUS_0xd40              0                   1

# %% [markdown]
# ## Making Dummies

# %%
df = pd.get_dummies(df, drop_first=True)
df.head()
# Out:
#                      Age  Annual_Income  Num_Bank_Accounts  Num_Credit_Card  \
# ID     Customer_ID
# 0x1602 CUS_0xd40    23.0       19114.12                3.0              4.0
# 0x1603 CUS_0xd40    23.0       19114.12                3.0              4.0
# 0x1604 CUS_0xd40    23.0       19114.12                3.0              4.0
# 0x1605 CUS_0xd40    23.0       19114.12                3.0              4.0
# 0x1606 CUS_0xd40    23.0       19114.12                3.0              4.0
#
#                     Num_of_Delayed_Payment  Credit_Utilization_Ratio  \
# ID     Customer_ID
# 0x1602 CUS_0xd40                       7.0                 26.822620
# 0x1603 CUS_0xd40                       6.0                 31.944960
# 0x1604 CUS_0xd40                       7.0                 28.609352
# 0x1605 CUS_0xd40                       4.0                 31.377862
# 0x1606 CUS_0xd40                       6.0                 24.797347
#
#                     Total_EMI_per_month  Credit_Score  \
# ID     Customer_ID
# 0x1602 CUS_0xd40              49.574949             1
# 0x1603 CUS_0xd40              49.574949             1
# 0x1604 CUS_0xd40              49.574949             1
# 0x1605 CUS_0xd40              49.574949             1
# 0x1606 CUS_0xd40              49.574949             1
#
#                     Credit_History_Age_Formated  Auto_Loan  \
# ID     Customer_ID
# 0x1602 CUS_0xd40                          265.0          1
# 0x1603 CUS_0xd40                          266.0          1
# 0x1604 CUS_0xd40                          267.0          1
# 0x1605 CUS_0xd40                          268.0          1
# 0x1606 CUS_0xd40                          269.0          1
#
#                     Credit-Builder_Loan  Personal_Loan  Home_Equity_Loan  \
# ID     Customer_ID
# 0x1602 CUS_0xd40                      1              1                 1
# 0x1603 CUS_0xd40                      1              1                 1
# 0x1604 CUS_0xd40                      1              1                 1
# 0x1605 CUS_0xd40                      1              1                 1
# 0x1606 CUS_0xd40                      1              1                 1
#
#                     Mortgage_Loan  Student_Loan  Debt_Consolidation_Loan  \
# ID     Customer_ID
# 0x1602 CUS_0xd40                0             0                        0
# 0x1603 CUS_0xd40                0             0                        0
# 0x1604 CUS_0xd40                0             0                        0
# 0x1605 CUS_0xd40                0             0                        0
# 0x1606 CUS_0xd40                0             0                        0
#
#                     Payday_Loan  Missed_Payment_Day  Payment_of_Min_Amount_Yes
# ID     Customer_ID
# 0x1602 CUS_0xd40              0                   1                          0
# 0x1603 CUS_0xd40              0                   0                          0
# 0x1604 CUS_0xd40              0                   1                          0
# 0x1605 CUS_0xd40              0                   1                          0
# 0x1606 CUS_0xd40              0                   1                          0

# %% [markdown]
# ## Min Max Scaling

# %% [markdown]
# I'm scaling the numeric values to minimize the bias because of the diverse data.

# %%
y = df.Credit_Score
x = df.drop(columns='Credit_Score')

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(x) 
scaled_values = scaler.transform(x)
x.loc[:,:] = scaled_values

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

corr = x.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style('white'):
    f, ax = plt.subplots(figsize=(17, 15))
    ax = sns.heatmap(corr, mask=mask, square=True, annot = True, fmt = '.1f', vmin=-1, vmax=1)

# %% [markdown]
# I plotted the correlation matrix to be sure that no feature is heavily correlated with each other.

# %% [markdown]
# # Splitting Train and Test Sets

# %%
from sklearn.model_selection import train_test_split

# %%
from random import shuffle

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, shuffle=True, stratify=y, random_state=43)

# %% [markdown]
# # Training the Model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(random_state=43)
model.fit(x_train, y_train)
prediction = model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
labels = np.unique(y_test)
conf = confusion_matrix(y_test, prediction)
conf_p = conf/sum(conf)
conf = pd.DataFrame(conf, index=labels, columns=labels)
conf_p = pd.DataFrame(conf_p, index=labels, columns=labels)

# %%
with sns.axes_style('white'):
    fig, ax =plt.subplots(1,2, figsize=(15, 5))
    sns.heatmap(conf, annot = True, fmt = '.0f',  ax=ax[0])
    sns.heatmap(conf_p, annot = True, fmt = '.2f', vmin=0, vmax=1,  ax=ax[1])

# %% [markdown]
# The dataset is imbalanced and even though I didn't address it, the imbalance didn't seem to have a big impact on the model's predictive capacity.

# %% [markdown]
# # Saving the Model

# %%
import pickle

# %% [markdown]
# I'm saving the model and the scaler to use in the streamlit app.

# %%
pickle.dump(model, open('../models/model.obj', 'wb'))

# %%
pickle.dump(scaler, open('../models/scaler.obj', 'wb'))
